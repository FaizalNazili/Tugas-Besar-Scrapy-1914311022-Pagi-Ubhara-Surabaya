# %%
! git clone https://github.com/FaizalNazili/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya.git
# Out:
# fatal: destination path 'Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya' already exists and is not an empty directory.

# %%
from bs4 import BeautifulSoup as bs 
import os
import re
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
folder = "/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt"
for filename in os.listdir(folder):
    if filename.endswith(".html"):
        fname = os.path.join(folder, filename)
        print("Filename: {}".format(fname))
# Out:
# Filename: /content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1147-reinforcements-arrive.html
# Filename: /content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-478-dimensions-child.html
# Filename: /content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-486-verify.html
# Filename: /content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1044-viper.html
# Filename: /content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-483-the-earth-federation-united-front.html
# Filename: /content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1146-spatial-gate.html
# Filename: /content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1043-prehistoric-times.html
# ...

# %%
def teks_utuh(fname):
    with open(fname, "r", encoding="utf8") as f:
        soup = bs(f.read(), "html.parser")
        isi = soup.find_all("div",{"id": "asli"}, "p")
        pola = re.compile('<.*?>')
        teks_awal = re.sub(pola, '', str(isi)) 
        new = teks_awal[1:teks_awal.find('&lt; Chapter')] 
        teks_bersih = new.replace(". ", ".").replace(" , ", " ").replace("www.worldnovel.online", "").replace("\xa0", " ")
        return teks_bersih

# %%
# def Convert(string):
#     li = list(string.split(" "))
#     return li

# %%
another1 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1043-prehistoric-times.html")
another2 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1044-viper.html")
another3 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1045-vipers-poison.html")
another4 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1046-wind-and-thunder-beast-king.html")
another5 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1047-meditation-ground.html")
another6 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1048-golden.html")
another7 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1049-world-sword.html")
another8 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1050-reincarnation.html")
another9 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1051-undercurrent.html")
another10 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/another-worlds-versatile-crafting-master-chapter-1052-fleet.html")

# %%
ever1 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1143-dispatched.html")
ever2 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1144-breaking-out-from-the-ambush.html")
ever3 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1145-entering-the-battlefield.html")
ever4 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1146-spatial-gate.html")
ever5 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1147-reinforcements-arrive.html")
ever6 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1148-graveyard-of-divine-dragons.html")
ever7 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1149-tomb.html")
ever8 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1150-mid-grade-divine-artifact.html")
ever9 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1151-hidden-black-hand.html")
ever10 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/everlasting-chapter-1152-the-dark-kirin-appears.html")

# %%
scholar1 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1092-winter-has-arrived-in-silicon-valley.html")
scholar2 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1093-perelmans-visi.html")
scholar3 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1094-price-is-just-one-of-the-reasons.html")
scholar4 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1095-pigs-are-flying.html")
scholar5 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1096-handshake-between-two-giants.html")
scholar6 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1097-second-closed-beta.html")
scholar7 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1098-a-taste-of-evil.html")
scholar8 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1099-player-evaluation.html")
scholar9 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1100-the-terrifying-fields-medalis.html")
scholar10 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/scholars-advanced-technological-system-chapter-1101-something-is-wrong.html")

# %%
super1 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-100-new-partner-new-case-and-new-star.html")
super2 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-91-part-time-patrol-officers.html")
super3 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-92-patrol-and-harvest.html")
super4 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-93-great-loot-and-bittersweet-ability.html")
super5 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-94-virtue-and-wit.html")
super6 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-95-bet-dinner-and-pick-me-up.html")
super7 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-96-extra-meal-and-pleasant-surprise.html")
super8 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-97-brocks-blessing-and-an-unexpected-offer.html")
super9 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-98-good-news-and-bad-news.html")
super10 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-detective-in-the-fictional-world-chapter-99-cash-over-promotion.html")

# %%
superusb1 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-477-to-live-in-the-face-of-death.html")
superusb2 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-478-dimensions-child.html")
superusb3 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-479-appreciation.html")
superusb4 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-480-transformation.html")
superusb5 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-481-wipe-out.html")
superusb6 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-482-the-law-of-causality.html")
superusb7 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-483-the-earth-federation-united-front.html")
superusb8 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-484-secret-meeting.html")
superusb9 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-485-weeping-angel.html")
superusb10 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311022-Pagi-Ubhara-Surabaya/Tubes3/Chapt/super-usb-bahasa-chapter-486-verify.html")

# %%
# list_another1 = Convert(another1)
# list_another2 = Convert(another2)
# list_another3 = Convert(another3)
# list_another4 = Convert(another4)
# list_another5 = Convert(another5)
# list_another6 = Convert(another6)
# list_another7 = Convert(another7)
# list_another8 = Convert(another8)
# list_another9 = Convert(another9)
# list_another10 = Convert(another10)

# %%
# cars = {'Konten': [list_another1, list_another2, list_another3, list_another4, list_another5, list_another6, list_another7, list_another8, list_another9, list_another10],
#         'Judul': ["Chapter 616", "Chapter 617", "Chapter 618", "Chapter 619", "Chapter 620", "Chapter 621", "Chapter 622", "Chapter 623", "Chapter 624", "Chapter 625"]}

# df = pd.DataFrame(cars, columns= ['Judul', 'Konten'])

# print (df)
# df.to_csv ('./Novel/export_dataframe.csv', index = False, header=True)

# %%
# Data_Novel = pd.read_csv("./Novel/export_dataframe.csv", usecols=["Konten"])
# Data_Novel.columns = ["Konten"]
# Data_Novel.head()

# %%
tfidf = TfidfVectorizer()

# %%
doc_a = tfidf.fit_transform([another1, another2, another3, another4, another5, another6, another7, another8, another9, another10])

# %%
doc_ever = tfidf.fit_transform([ever1, ever2 ,ever3 ,ever4 ,ever5 ,ever6 ,ever7 ,ever8 ,ever9 ,ever10])

# %%
doc_scholar = tfidf.fit_transform([scholar1, scholar2 ,scholar3 ,scholar4 ,scholar5 ,scholar6 ,scholar7 ,scholar8 ,scholar9 ,scholar10])

# %%
doc_super = tfidf.fit_transform([super1, super2 ,super3 ,super4 ,super5 ,super6 ,super7 ,super8 ,super9 ,super10])

# %%
doc_superusb = tfidf.fit_transform([superusb1, superusb2 ,superusb3 ,superusb4 ,superusb5 ,superusb6 ,superusb7 ,superusb8 ,superusb9 ,superusb10])

# %%
def nilai_tfidf(doc): 
    feature_names = tfidf.get_feature_names()
    for col in doc.nonzero()[1]:
        print (feature_names[col], ' - ', doc[0, col])

# %%
def top10(doc):
    feature_array = np.array(tfidf.get_feature_names())
    tfidf_sorting = np.argsort(doc.toarray()).flatten()[::-1]
    n = 10
    top_n = feature_array[tfidf_sorting][:n]
    print(top_n)

# %%
nilai_tfidf(doc_a)
# Out:
# Streaming output truncated to the last 5000 lines.
# demolished  -  0.0
# currently  -  0.0
# chase  -  0.0
# budge  -  0.0
# object  -  0.0
# exits  -  0.0
# clack  -  0.0
# city  -  0.0
# industrial  -  0.0
# audiovisual  -  0.0
# assault  -  0.0
# functionalities  -  0.0
# chemical  -  0.0
# freely  -  0.0
# modern  -  0.0
# daytime  -  0.0
# capable  -  0.0
# arriving  -  0.0
# prolific  -  0.0
# potential  -  0.0
# aback  -  0.0
# damaged  -  0.0
# react  -  0.0
# collect  -  0.0
# arched  -  0.0
# chairmanship  -  0.0
# hint  -  0.0
# operations  -  0.0
# consciousness  -  0.0
# material  -  0.0
# even  -  0.0
# knight  -  0.0
# moving  -  0.0
# main  -  0.0
# breached  -  0.0
# days  -  0.0
# ding  -  0.0
# positions  -  0.0
# headed  -  0.0
# crackled  -  0.0
# chunks  -  0.0
# crowd  -  0.0
# awe  -  0.0
# coup  -  0.0
# another  -  0.0
# obtained  -  0.0
# injury  -  0.0
# difficult  -  0.0
# forehead  -  0.0
# callback  -  0.0
# defensive  -  0.0
# blockade  -  0.0
# ...

# %%
top10(doc_a)
# Out:
# ['perspective' 'himself' 'plowing' 'floors' 'edged' 'photos' 'aghh'
#  'inmates' 'control' 'infected']

# %%
nilai_tfidf(doc_ever)
# Out:
# Streaming output truncated to the last 5000 lines.
# procedures  -  0.02848490861725306
# passage  -  0.01898993907816871
# drawback  -  0.009494969539084354
# drained  -  0.008441708322969846
# lowered  -  0.00622324137108141
# observing  -  0.005667292957414658
# agile  -  0.00622324137108141
# frail  -  0.00685352369901267
# delivered  -  0.00622324137108141
# dripping  -  0.005169980154966904
# hair  -  0.01244648274216282
# appearance  -  0.009494969539084354
# listen  -  0.010852859416252449
# fate  -  0.01416031800934374
# because  -  0.008441708322969846
# circle  -  0.034003757744487946
# including  -  0.034003757744487946
# grew  -  0.010339960309933808
# age  -  0.02489296548432564
# literally  -  0.005667292957414658
# invading  -  0.005667292957414658
# onlookers  -  0.00685352369901267
# adjutant  -  0.010852859416252449
# morning  -  0.00622324137108141
# rear  -  0.01370704739802534
# numbness  -  0.02848490861725306
# deadpan  -  0.017001878872243973
# ...

# %%
top10(doc_ever)
# Out:
# ['paid' 'heart' 'past' 'aghh' 'conference' 'charging' 'fireworks'
#  'mumbled' 'evacuate' 'driving']

# %%
nilai_tfidf(doc_scholar)
# Out:
# mysterious  -  0.012971205211832655
# gulps  -  0.009696655754795626
# invisible  -  0.02184363393976327
# blamed  -  0.01444364005978146
# deadpan  -  0.01444364005978146
# monitoring  -  0.018569084482726234
# numbered  -  0.011726279286429522
# actually  -  0.02184363393976327
# keen  -  0.01444364005978146
# cord  -  0.009696655754795626
# completed  -  0.018569084482726234
# low  -  0.016245754668869686
# bearer  -  0.024228097990839883
# elaborate  -  0.018569084482726234
# breathe  -  0.01444364005978146
# negative  -  0.018569084482726234
# different  -  0.016245754668869686
# heavy  -  0.01444364005978146
# just  -  0.02184363393976327
# heaven  -  0.01444364005978146
# drove  -  0.012971205211832655
# flaws  -  0.009696655754795626
# accordingly  -  0.012971205211832655
# intentions  -  0.00884576078888788
# established  -  0.00884576078888788
# namibia  -  0.010647875397976105
# carapace  -  0.02184363393976327
# energy  -  0.02184363393976327
# ...

# %%
top10(doc_scholar)
# Out:
# ['mammoth' 'ongoings' 'meat' 'beneficial' 'only' 'agh' 'ended'
#  'extinguished' 'nationality' 'as']

# %%
nilai_tfidf(doc_super)
# Out:
# drove  -  0.023254847129080842
# crushed  -  0.017295315530507845
# lifted  -  0.012483858361242115
# dead  -  0.008597786683282338
# hours  -  0.011335783931934847
# dirt  -  0.008597786683282338
# clearer  -  0.017295315530507845
# four  -  0.023254847129080842
# echoed  -  0.023254847129080842
# distorted  -  0.023254847129080842
# eco  -  0.023254847129080842
# aghh  -  0.010323110516451827
# just  -  0.01976874462205283
# because  -  0.01976874462205283
# delighted  -  0.01976874462205283
# level  -  0.02761842604695967
# doubting  -  0.023254847129080842
# blamed  -  0.023254847129080842
# enlarged  -  0.023254847129080842
# exerted  -  0.011335783931934847
# antimeme  -  0.01976874462205283
# departments  -  0.010323110516451827
# emerged  -  0.01976874462205283
# desk  -  0.01976874462205283
# are  -  0.01976874462205283
# gesture  -  0.023254847129080842
# instant  -  0.017295315530507845
# hook  -  0.01976874462205283
# frightened  -  0.023254847129080842
# ...

# %%
top10(doc_super)
# Out:
# ['invented' 'jolt' 'encounters' 'africa' 'ends' 'locked' 'afraid' 'ever'
#  'disk' 'having']

# %%
nilai_tfidf(doc_superusb)
# Out:
# Streaming output truncated to the last 5000 lines.
# still  -  0.0031711217289316315
# allow  -  0.005671415996718846
# ever  -  0.011342831993437693
# countless  -  0.004604421575987092
# seconds  -  0.008361954550681935
# within  -  0.0069467238221950145
# dropping  -  0.007291306231938233
# drive  -  0.010186504292633788
# usb  -  0.010186504292633788
# sharp  -  0.005093252146316894
# flash  -  0.010186504292633788
# steady  -  0.014582612463876467
# stream  -  0.007291306231938233
# life  -  0.010420085733292521
# die  -  0.039699911977031925
# going  -  0.010186504292633788
# cautiously  -  0.006379031360962307
# tremendous  -  0.006379031360962307
# gave  -  0.005093252146316894
# burst  -  0.004604421575987092
# revealed  -  0.006379031360962307
# give  -  0.005093252146316894
# piercing  -  0.006379031360962307
# blur  -  0.005671415996718846
# started  -  0.011422418795014443
# vision  -  0.005671415996718846
# part  -  0.006379031360962307
# ...

# %%
top10(doc_superusb)
# Out:
# ['the' 'to' 'of' 'this' 'and' 'in' 'man' 'was' 'he' 'that']

# %%
! git clone https://github.com/BaghasWahyu/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya.git
# Out:
# fatal: destination path 'Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya' already exists and is not an empty directory.

# %%
from bs4 import BeautifulSoup as bs 
import os
import re
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
folder = "/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter"
for filename in os.listdir(folder):
    if filename.endswith(".html"):
        fname = os.path.join(folder, filename)
        print("Filename: {}".format(fname))
# Out:
# Filename: /content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-744-half-step-eighth-eminence-meng-chuan.html
# Filename: /content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-445.html
# Filename: /content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-437.html
# Filename: /content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-748-the-fate-of-celestial-thearch-myriad-star-final-chapter-of-volume.html
# Filename: /content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-196.html
# Filename: /content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-439.html
# Filename: /content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-620-life-tutor-chicken-soup-for-the-soul.html
# ...

# %%
def teks_utuh(fname):
    with open(fname, "r", encoding="utf8") as f:
        soup = bs(f.read(), "html.parser")
        isi = soup.find_all("div",{"id": "asli"}, "p")
        pola = re.compile('<.*?>')
        teks_awal = re.sub(pola, '', str(isi)) 
        new = teks_awal[1:teks_awal.find('&lt; Chapter')] 
        teks_bersih = new.replace(". ", ".").replace(" , ", " ").replace("www.worldnovel.online", "").replace("\xa0", " ")
        return teks_bersih

# %%
# def Convert(string):
#     li = list(string.split(" "))
#     return li

# %%
agt1 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-616-appreciation-of-a-major-character.html")
agt2 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-617-sun-mos-on-the-spot-guidance.html")
agt3 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-618-gathering-of-geniuses.html")
agt4 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-619-xuanyuan-po-your-acting-skills-are-so-exaggerated.html")
agt5 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-620-life-tutor-chicken-soup-for-the-soul.html")
agt6 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-621-mysterious-species-of-darkness-strange-ability.html")
agt7 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-622-sorry-i-didnt-hold-back-enough-and-injured-you.html")
agt8 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-623-im-fighting-for-my-teacher.html")
agt9 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-624-transforming-into-wind-ceremony-of-death.html")
agt10 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/absolute-great-teacher-chapter-625-sliding-into-the-dark-abyss.html")

# %%
aea1 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-743-epiphany.html")
aea2 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-744-half-step-eighth-eminence-meng-chuan.html")
aea3 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-745-fate.html")
aea4 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-746-the-sound-on-the-mountaintop.html")
aea5 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-747-first-meeting-with-fiend-mountains-owner.html")
aea6 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-748-the-fate-of-celestial-thearch-myriad-star-final-chapter-of-volume.html")
aea7 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-749-tenacity-of-life.html")
aea8 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-750-more-than-ten-thousand-years-later.html")
aea9 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-751-natural-accomplishment.html")
aea10 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-752-essence-soul-eighth-tribulation-lifeform.html")
aea11 = teks_utuh ("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/archean-eon-art-chapter-753-treatment.html")

# %%
csg1 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2948-l-ei-shiguang.html")
csg2 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2949-manifestation-of-the-ways.html")
csg3 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2950-grand-exalt.html")
csg4 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2951-hitchhiking.html")
csg5 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2952-someone-to-run-errands.html")
csg6 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2953-reaching-the-ice-pole-plane.html")
csg7 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2954-the-lightning-god-clan-retreats.html")
csg8 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2955-the-saint-monarch-passes.html")
csg9 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2956-the-trade-association-of-five-regions.html")
csg10 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2957-proceeding-to-the-heavenly-crane-clan.html")
csg11 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/chaotic-sword-god-chapter-2958-seeing-he-qianqian-again.html")

# %%
rkr1 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-435.html")
rkr2 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-436.html")
rkr3 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-437.html")
rkr4 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-438.html")
rkr5 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-439.html")
rkr6 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-440.html")
rkr7 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-441.html")
rkr8 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-442.html")
rkr9 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-443.html")
rkr10 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-444.html")
rkr11 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/rkr-chapter-445.html")

# %%
rop1 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-194.html")
rop2 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-195.html")
rop3 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-196.html")
rop4 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-197.html")
rop5 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-198.html")
rop6 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-199.html")
rop7 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-200.html")
rop8 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-201.html")
rop9 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-202.html")
rop10 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-203.html")
rop11 = teks_utuh("/content/Tugas-Besar-Scrapy-1914311046-Pagi-Ubhara-Surabaya/Novel/Chapter/the-rise-of-phoenixes-chapter-204.html")

# %%
# list_agt1 = Convert(agt1)
# list_agt2 = Convert(agt2)
# list_agt3 = Convert(agt3)
# list_agt4 = Convert(agt4)
# list_agt5 = Convert(agt5)
# list_agt6 = Convert(agt6)
# list_agt7 = Convert(agt7)
# list_agt8 = Convert(agt8)
# list_agt9 = Convert(agt9)
# list_agt10 = Convert(agt10)

# %%
# cars = {'Konten': [list_agt1, list_agt2, list_agt3, list_agt4, list_agt5, list_agt6, list_agt7, list_agt8, list_agt9, list_agt10],
#         'Judul': ["Chapter 616", "Chapter 617", "Chapter 618", "Chapter 619", "Chapter 620", "Chapter 621", "Chapter 622", "Chapter 623", "Chapter 624", "Chapter 625"]}

# df = pd.DataFrame(cars, columns= ['Judul', 'Konten'])

# print (df)
# df.to_csv ('./Novel/export_dataframe.csv', index = False, header=True)

# %%
# Data_Novel = pd.read_csv("./Novel/export_dataframe.csv", usecols=["Konten"])
# Data_Novel.columns = ["Konten"]
# Data_Novel.head()

# %%
tfidf = TfidfVectorizer()

# %%
doc_a = tfidf.fit_transform([agt1, agt2, agt3, agt4, agt5, agt6, agt7, agt8, agt9, agt10])

# %%
doc_aea = tfidf.fit_transform([aea1, aea2 ,aea3 ,aea4 ,aea5 ,aea6 ,aea7 ,aea8 ,aea9 ,aea10, aea11])

# %%
doc_csg = tfidf.fit_transform([csg1, csg2 ,csg3 ,csg4 ,csg5 ,csg6 ,csg7 ,csg8 ,csg9 ,csg10, csg11])

# %%
doc_rkr = tfidf.fit_transform([rkr1, rkr2 ,rkr3 ,rkr4 ,rkr5 ,rkr6 ,rkr7 ,rkr8 ,rkr9 ,rkr10, rkr11])

# %%
doc_rop = tfidf.fit_transform([rop1, rop2 ,rop3 ,rop4 ,rop5 ,rop6 ,rop7 ,rop8 ,rop9 ,rop10, rop11])

# %%
def nilai_tfidf(doc): 
    feature_names = tfidf.get_feature_names()
    for col in doc.nonzero()[1]:
        print (feature_names[col], ' - ', doc[0, col])

# %%
def top10(doc):
    feature_array = np.array(tfidf.get_feature_names())
    tfidf_sorting = np.argsort(doc.toarray()).flatten()[::-1]
    n = 10
    top_n = feature_array[tfidf_sorting][:n]
    print(top_n)

# %%
nilai_tfidf(doc_a)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# experimental  -  0.009871415377811632
# perfect  -  0.008776395649437866
# eyes  -  0.009814486880078934
# intoxicated  -  0.011283141340667593
# wait  -  0.006469973423026988
# ever  -  0.008776395649437866
# today  -  0.008776395649437866
# hands  -  0.005891983393954268
# used  -  0.005891983393954268
# knew  -  0.005374953694653223
# smashed  -  0.009871415377811632
# right  -  0.005374953694653223
# never  -  0.011783966787908535
# ancestor  -  0.011283141340667593
# back  -  0.005891983393954268
# got  -  0.011783966787908535
# smiled  -  0.006469973423026988
# hence  -  0.004907243440039467
# blown  -  0.011283141340667593
# matter  -  0.007125244473523012
# fists  -  0.006469973423026988
# tell  -  0.007125244473523012
# possibly  -  0.008776395649437866
# first  -  0.02356793357581707
# well  -  0.006469973423026988
# feeling  -  0.005891983393954268
# see  -  0.004907243440039467
# done  -  0.008776395649437866
# ...

# %%
top10(doc_a)
# Out:
# ['the' 'to' 'han' 'ma' 'xi' 'he' 'was' 'and' 'jianmu' 'of']

# %%
nilai_tfidf(doc_aea)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# indeed  -  0.0
# mantle  -  0.0
# afford  -  0.0
# identity  -  0.0
# chaos  -  0.0
# arrogant  -  0.0
# least  -  0.0
# kill  -  0.0
# incomparably  -  0.0
# death  -  0.0
# city  -  0.0
# one  -  0.0
# notification  -  0.0
# learning  -  0.0
# conducting  -  0.0
# ate  -  0.0
# completely  -  0.0
# keep  -  0.0
# nurturing  -  0.0
# fainted  -  0.0
# impolitely  -  0.0
# hmm  -  0.0
# address  -  0.0
# defensive  -  0.0
# forth  -  0.0
# inferior  -  0.0
# destined  -  0.0
# himself  -  0.0
# divine  -  0.0
# python  -  0.0
# give  -  0.0
# chess  -  0.0
# corner  -  0.0
# interesting  -  0.0
# plus  -  0.0
# concluded  -  0.0
# increase  -  0.0
# meanings  -  0.0
# guarantee  -  0.0
# alright  -  0.0
# everyone  -  0.0
# opportunity  -  0.0
# nerves  -  0.0
# breathed  -  0.0
# arm  -  0.0
# history  -  0.0
# colored  -  0.0
# reluctant  -  0.0
# advantageous  -  0.0
# derived  -  0.0
# discussion  -  0.0
# ...

# %%
top10(doc_aea)
# Out:
# ['pierced' 'got' 'proficient' 'exchange' 'expect' 'potions' 'books'
#  'habit' 'hundred' 'creatures']

# %%
nilai_tfidf(doc_csg)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# che  -  0.02598639842641956
# cultivators  -  0.014282627978448465
# happier  -  0.032209471038350125
# clapped  -  0.00959488901393176
# persist  -  0.007873498674359962
# flawless  -  0.04883308176455312
# alright  -  0.014380705427569893
# borrowed  -  0.014282627978448465
# alliance  -  0.02598639842641956
# figure  -  0.010736490346116708
# dread  -  0.021472980692233416
# peak  -  0.02441654088227656
# clad  -  0.014282627978448465
# buddha  -  0.014282627978448465
# lowering  -  0.01220827044113828
# living  -  0.04294596138446683
# ah  -  0.019763325814489
# juiciest  -  0.039526651628978
# before  -  0.0856957678706908
# itself  -  0.010736490346116708
# personality  -  0.06716422309752232
# from  -  0.02856525595689693
# moderation  -  0.09594889013931761
# emotional  -  0.008662132808806521
# generals  -  0.008662132808806521
# depending  -  0.008662132808806521
# hard  -  0.0433106640440326
# ...

# %%
top10(doc_csg)
# Out:
# ['moving' 'bid' 'brought' 'hua' 'giving' 'each' 'eating' 'birth' 'past'
#  'eruption']

# %%
nilai_tfidf(doc_rkr)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# gentleman  -  0.004530778402855957
# depended  -  0.009508347233465584
# eyeballs  -  0.05436934083427149
# low  -  0.010713673949506166
# applause  -  0.022653892014279784
# learning  -  0.04530778402855957
# stomped  -  0.018123113611423828
# living  -  0.009061556805711914
# guide  -  0.019016694466931168
# makes  -  0.006367850957784084
# gold  -  0.18576191451709426
# buddha  -  0.00849733325043458
# improvement  -  0.00849733325043458
# contemplated  -  0.01607051092425925
# stabilize  -  0.01910355287335225
# curved  -  0.027184670417135744
# lived  -  0.022653892014279784
# base  -  0.07702323284855127
# downward  -  0.005356836974753083
# alliance  -  0.021427347899012333
# awu  -  0.009850015341046658
# front  -  0.009061556805711914
# brightened  -  0.022653892014279784
# actually  -  0.00849733325043458
# limbs  -  0.11326946007139893
# cried  -  0.005834202123609329
# anymore  -  0.12233101687711084
# ...

# %%
top10(doc_rkr)
# Out:
# ['seriously' 'stage' 'shoulders' 'froze' 'limbs' 'hanxi' 'gold' 'greater'
#  'gentleness' 'anymore']

# %%
nilai_tfidf(doc_rop)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# dojo  -  0.0
# clap  -  0.0
# miao  -  0.0
# rules  -  0.0
# less  -  0.0
# brother  -  0.0
# pass  -  0.0
# leader  -  0.0
# attacks  -  0.0
# observing  -  0.0
# smith  -  0.0
# goal  -  0.0
# dust  -  0.0
# knows  -  0.0
# persisted  -  0.0
# least  -  0.0
# deep  -  0.0
# mind  -  0.0
# appreciate  -  0.0
# gui  -  0.0
# determined  -  0.0
# murmured  -  0.0
# almost  -  0.0
# humble  -  0.0
# ascending  -  0.0
# esteemed  -  0.0
# admit  -  0.0
# retaliate  -  0.0
# like  -  0.0
# idea  -  0.0
# headful  -  0.0
# benefit  -  0.0
# compare  -  0.0
# directions  -  0.0
# examples  -  0.0
# daughter  -  0.0
# pain  -  0.0
# meters  -  0.0
# send  -  0.0
# earth  -  0.0
# path  -  0.0
# gigantic  -  0.0
# count  -  0.0
# dare  -  0.0
# exaggerated  -  0.0
# became  -  0.0
# flexing  -  0.0
# hit  -  0.0
# dragon  -  0.0
# resolve  -  0.0
# fine  -  0.0
# peers  -  0.0
# medal  -  0.0
# fighting  -  0.0
# fire  -  0.0
# ...

# %%
top10(doc_rop)
# Out:
# ['ah' 'fish' 'return' 'ruptured' 'fiancee' 'flaws' 'stir' 'doing'
#  'hitting' 'retreated']
